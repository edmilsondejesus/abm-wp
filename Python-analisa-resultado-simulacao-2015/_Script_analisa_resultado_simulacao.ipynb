# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor
import os
import time

# ==========================================
# 1. Configuration
# ==========================================
# Target data file check
results_path = ".."
target_csv = os.path.join(results_path,'resultados', 'simulacao_hindcasting_2016_2025.csv')

# List of notebooks to be executed in sequence after simulation execution in Gama
scripts = [
"Script_analise_renda_x_consumo_por_setor_censitario_2015.ipynb", 
"Script_gera_consumo_real_historico.ipynb", 
"Script_compara_resultados_transicao_perfil_2016_2025_3_graficos_mensal_simbolos.ipynb",
"Script_compara_resultados_mensal_2016_2025_lstm_sarima_sem_os_cenarios.ipynb",
]

# ==========================================
# 2. Notebook Execution Pipeline
# ==========================================
print("="*60)
print("Processing Notebooks Final Pipeline - Simulation 2016 - 2025")
print("="*60)

if not os.path.exists(target_csv):
    print(f"Error: Required data file {os.path.basename(target_csv)} not found.")
    print("Please ensure the simulation results are available before running.")
else:
    print(f"Data detected. Processing {len(scripts)} notebooks...\n")
    
    # Configure the processor (25-minute timeout per notebook for LSTM training)
    processor = ExecutePreprocessor(timeout=1500, kernel_name='python3')

    for script in scripts:
        if os.path.exists(script):
            start_clock = time.time()
            print(f"Executing: {script}...", end=" ", flush=True)
            try:
                # Load notebook content
                with open(script, 'r', encoding='utf-8') as f:
                    nb_content = nbformat.read(f, as_version=4)
                
                # Execute notebook and generate outputs
                processor.preprocess(nb_content, {'metadata': {'path': os.getcwd()}})
                
                # Save the notebook with updated results/cells
                with open(script, 'w', encoding='utf-8') as f:
                    nbformat.write(nb_content, f)
                
                end_clock = time.time() - start_clock
                print(f"Done ({end_clock:.1f}s)")
                
            except Exception as error:
                print(f"Failed: {str(error)}")
        else:
            print(f"Warning: File {script} not found in the directory.")

print("\n" + "="*60)
print("Pipeline execution completed.")
print("="*60)
# Out:
# ============================================================
# Processing Notebooks Final Pipeline - Simulation 2016 - 2025
# ============================================================
# Data detected. Processing 4 notebooks...
#
# Warning: File Script_analise_renda_x_consumo_por_setor_censitario_2015.ipynb not found in the directory.
# Executing: Script_gera_consumo_real_historico.ipynb... Done (7.6s)
# Executing: Script_compara_resultados_transicao_perfil_2016_2025_3_graficos_mensal_simbolos.ipynb... Done (15.3s)
# Executing: Script_compara_resultados_mensal_2016_2025_lstm_sarima_sem_os_cenarios.ipynb... Done (5.7s)
#
# ============================================================
# Pipeline execution completed.
# ============================================================
